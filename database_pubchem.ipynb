# %%
import os,re,sys,pickle,datetime,time,random,itertools
import warnings
warnings.filterwarnings("ignore")
import numpy as np
#np.set_printoptions(threshold=sys.maxsize)
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import openpyxl
from openpyxl import load_workbook
import pandas as pd
import math
import seaborn as sns 
import umap
import umap.plot
from PIL import Image
from sklearn.cluster import KMeans
from sklearn import metrics
from sklearn.multioutput import MultiOutputRegressor
from sklearn.neighbors import KNeighborsClassifier, NearestNeighbors
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler,MinMaxScaler,PolynomialFeatures
from sklearn.decomposition import PCA
import hdbscan
import sklearn.cluster as cluster
from sklearn.metrics import adjusted_rand_score, adjusted_mutual_info_score
randomstate = 42
import rdkit
from rdkit import Chem
from rdkit.Chem import AllChem, MolFromSmiles, PandasTools, Descriptors, Draw, PropertyMol, rdmolfiles, rdFMCS
from rdkit import RDConfig
from rdkit.ML.Descriptors import MoleculeDescriptors
from rdkit.Chem.Draw import MolsToGridImage, IPythonConsole, rdMolDraw2D
from rdkit.Chem.Draw.MolDrawing import MolDrawing,DrawingOptions, Font
DrawingOptions.bondLineWidth=1.8
DrawingOptions.includeAtomNumbers=False
size = (150, 150)
import plotly.express as px
import molplotly
import mols2grid
from chembl_webresource_client.new_client import new_client
from IPython.display import SVG
import pubchempy as pcp
from pubchempy import get_compounds, Compound
import mordred
from mordred import Calculator, descriptors
from tqdm import tqdm

def embed(mol):
    mol_with_H = Chem.AddHs(mol)
    Chem.AllChem.EmbedMolecule(mol_with_H)
    Chem.AllChem.MMFFOptimizeMolecule(mol_with_H)
    return mol_with_H

# %% [markdown]
# **Overview**
#
# PubChem is a database of 111 million chemical molecules and their activities against biological assays. PubChemPy connects with PubChem so requires internet access. Pubchem uses chemical IDs (CID) for compounds.
#
# https://pubchempy.readthedocs.io/en/latest/guide/gettingstarted.html
#
# https://github.com/mcs07/PubChemPy
#
#
# **Workflow**
#
# Download a csv file containing a collection of compounds from a PubChem search. Alternatively, go to https://pubchem.ncbi.nlm.nih.gov/source/ to search for various data sources within pubchem. Select one of interest e.g. DrugBank then click '[no.] live substances'. Click 'View or Download Structures in PubChem', 'Download', and 'CSV' under Summary tab.
#
# This notebook will clean that data, calculate descriptors, reduce dimensionality, and provide an updated CSV file.

# %%
df = pd.read_csv("PubChem_drugbank.csv")
df = df.drop(columns=['sid','sidsrcname', 'sidextid','sidsrcname', 'sidmdate','depdate', 'depcatg','annotation'])
df['cid'] = df['cid'].fillna(0)            # change errors to 0
df['cid'] = df['cid'].astype(np.int64)
df
# Out:
#            cid                                        subssynonym
# 0       445722  DB03657|N-(methoxycarbonyl)-beta-D-glucopyrano...
# 1       448006  (+)-2-(4-biphenyl)propionic acid|2-(1,1'-BIPHE...
# 2       444719                     METHIONINE PHOSPHONATE|DB02151
# 3         4064                meprobamate|Meprobamic acid|DB00371
# 4         2131       ambenonium|Ambenonum|Ambenonium Base|DB01122
# ...        ...                                                ...
# 13570    60852                Ibandronic Acid|Ibandronate|DB00710
# 13571    92196                           4-Methylaminorex|DB01447
# 13572     3776   isopropanol|Isopropyl alcohol|2-Propanol|DB02325
# 13573     6834  BROMPHENIRAMINE|1-(p-Bromophenyl)-1-(2-pyridyl...
# 13574  5326813                                     DAS869|DB02850
#
# [13575 rows x 2 columns]

# %% [markdown]
# Select a portion of dataset for analysis (optional)

# %%
#df2 = df.head(3000)
df2 = df
df2
# Out:
#            cid                                        subssynonym
# 0       445722  DB03657|N-(methoxycarbonyl)-beta-D-glucopyrano...
# 1       448006  (+)-2-(4-biphenyl)propionic acid|2-(1,1'-BIPHE...
# 2       444719                     METHIONINE PHOSPHONATE|DB02151
# 3         4064                meprobamate|Meprobamic acid|DB00371
# 4         2131       ambenonium|Ambenonum|Ambenonium Base|DB01122
# ...        ...                                                ...
# 13570    60852                Ibandronic Acid|Ibandronate|DB00710
# 13571    92196                           4-Methylaminorex|DB01447
# 13572     3776   isopropanol|Isopropyl alcohol|2-Propanol|DB02325
# 13573     6834  BROMPHENIRAMINE|1-(p-Bromophenyl)-1-(2-pyridyl...
# 13574  5326813                                     DAS869|DB02850
#
# [13575 rows x 2 columns]

# %% [markdown]
# Obtain smiles from pubchem using the CIDs (slow, 10k molecules = 1h)

# %%
smiles=[]
for i in tqdm(df2['cid'], desc = 'Extracting smiles'):    # tqdm adds progress bar
    try:
        c = pcp.Compound.from_cid(i)
        smiles.append(c.isomeric_smiles)
    except:
        smiles.append(np.nan)                             # any errors give NaN values
df2['smiles']=smiles
df2.dropna(axis=0,inplace=True)                           # drop any errors (rows)
df2.reset_index(drop=True,inplace=True)                   # reset the index
df2
# Out:
# Extracting smiles: 100%|██████████| 13575/13575 [1:31:35<00:00,  2.47it/s]
#            cid                                        subssynonym  \
# 0       445722  DB03657|N-(methoxycarbonyl)-beta-D-glucopyrano...
# 1       448006  (+)-2-(4-biphenyl)propionic acid|2-(1,1'-BIPHE...
# 2       444719                     METHIONINE PHOSPHONATE|DB02151
# 3         4064                meprobamate|Meprobamic acid|DB00371
# 4         2131       ambenonium|Ambenonum|Ambenonium Base|DB01122
# ...        ...                                                ...
# 10739    60852                Ibandronic Acid|Ibandronate|DB00710
# 10740    92196                           4-Methylaminorex|DB01447
# 10741     3776   isopropanol|Isopropyl alcohol|2-Propanol|DB02325
# 10742     6834  BROMPHENIRAMINE|1-(p-Bromophenyl)-1-(2-pyridyl...
# 10743  5326813                                     DAS869|DB02850
#
#                                                   smiles
# 0      COC(=O)N[C@H]1[C@@H]([C@H]([C@@H]([C@H](O1)CO)...
# 1                C[C@@H](C1=CC=C(C=C1)C2=CC=CC=C2)C(=O)O
# 2                                  CSCC[C@H](N)P(=O)(O)O
# 3                              CCCC(C)(COC(=O)N)COC(=O)N
# 4      CC[N+](CC)(CCNC(=O)C(=O)NCC[N+](CC)(CC)CC1=CC=...
# ...                                                  ...
# 10739                CCCCCN(C)CCC(O)(P(=O)(O)O)P(=O)(O)O
# 10740                          CC1C(OC(=N1)N)C2=CC=CC=C2
# 10741                                             CC(C)O
# 10742               CN(C)CCC(C1=CC=C(C=C1)Br)C2=CC=CC=N2
# 10743  CC1=C(C=CC(=C1C2=CC=C(C=C2)OC)S(=O)(=O)C)C(=O)...
#
# [10744 rows x 3 columns]

# %% [markdown]
# Make rdkit molecule objects

# %%
rdkit_obj = []
for i in tqdm(df2['smiles'], desc = 'Making rdkit objects'):    # tqdm adds progress bar
    try:
        x = Chem.MolFromSmiles(i)
        rdkit_obj.append(x)
    except:
        rdkit_obj.append(np.nan)                                # any errors give NaN values
df2['rdmol']=rdkit_obj
df3=df2.copy()
df3.dropna(axis=0,inplace=True)                                 # drop any errors (rows)
df3.reset_index(drop=True,inplace=True)                         # reset the index
df3


#df2['rdmol'] = df2['smiles'].map(lambda x: Chem.MolFromSmiles(x)) # faster method but doesnt handle errors
# Out:
# Making rdkit objects:   0%|          | 0/10744 [00:00<?, ?it/s]RDKit ERROR: [07:21:12] Explicit valence for atom # 7 Cl, 5, is greater than permitted
# Making rdkit objects: 100%|██████████| 10744/10744 [00:01<00:00, 6119.36it/s]
#            cid                                        subssynonym  \
# 0       445722  DB03657|N-(methoxycarbonyl)-beta-D-glucopyrano...
# 1       448006  (+)-2-(4-biphenyl)propionic acid|2-(1,1'-BIPHE...
# 2       444719                     METHIONINE PHOSPHONATE|DB02151
# 3         4064                meprobamate|Meprobamic acid|DB00371
# 4         2131       ambenonium|Ambenonum|Ambenonium Base|DB01122
# ...        ...                                                ...
# 10738    60852                Ibandronic Acid|Ibandronate|DB00710
# 10739    92196                           4-Methylaminorex|DB01447
# 10740     3776   isopropanol|Isopropyl alcohol|2-Propanol|DB02325
# 10741     6834  BROMPHENIRAMINE|1-(p-Bromophenyl)-1-(2-pyridyl...
# 10742  5326813                                     DAS869|DB02850
#
#                                                   smiles  \
# 0      COC(=O)N[C@H]1[C@@H]([C@H]([C@@H]([C@H](O1)CO)...
# 1                C[C@@H](C1=CC=C(C=C1)C2=CC=CC=C2)C(=O)O
# 2                                  CSCC[C@H](N)P(=O)(O)O
# 3                              CCCC(C)(COC(=O)N)COC(=O)N
# 4      CC[N+](CC)(CCNC(=O)C(=O)NCC[N+](CC)(CC)CC1=CC=...
# ...                                                  ...
# 10738                CCCCCN(C)CCC(O)(P(=O)(O)O)P(=O)(O)O
# 10739                          CC1C(OC(=N1)N)C2=CC=CC=C2
# 10740                                             CC(C)O
# 10741               CN(C)CCC(C1=CC=C(C=C1)Br)C2=CC=CC=N2
# 10742  CC1=C(C=CC(=C1C2=CC=C(C=C2)OC)S(=O)(=O)C)C(=O)...
#
#                                                    rdmol
# 0      <img data-content="rdkit/molecule" src="data:i...
# 1      <img data-content="rdkit/molecule" src="data:i...
# 2      <img data-content="rdkit/molecule" src="data:i...
# 3      <img data-content="rdkit/molecule" src="data:i...
# 4      <img data-content="rdkit/molecule" src="data:i...
# ...                                                  ...
# 10738  <img data-content="rdkit/molecule" src="data:i...
# 10739  <img data-content="rdkit/molecule" src="data:i...
# 10740  <img data-content="rdkit/molecule" src="data:i...
# 10741  <img data-content="rdkit/molecule" src="data:i...
# 10742  <img data-content="rdkit/molecule" src="data:i...
#
# [10743 rows x 4 columns]

# %% [markdown]
# Calculate optimized rdkit molecules (slow, 10k molecules = 1h)

# %%
opt_mols = []
for i in tqdm(df3['rdmol'], desc = 'Optimizing mols'):          # tqdm adds progress bar
    try:
        mol_with_H = Chem.AddHs(i)
        Chem.AllChem.EmbedMolecule(mol_with_H)
        Chem.AllChem.MMFFOptimizeMolecule(mol_with_H)
        opt_mols.append(mol_with_H)
    except:
        opt_mols.append(np.nan)                                 # any errors give NaN values
df3['rdmol_optimized']=opt_mols
df4=df3.copy()
df4.dropna(axis=0,inplace=True)                                 # drop any errors (rows)
df4.reset_index(drop=True,inplace=True)                         # reset the index
df4

#df3['rdmol_optimized'] = df2.rdmol.map(embed) # faster method but doesnt handle errors
# Out:
# Optimizing mols:   0%|          | 24/10743 [00:01<13:46, 12.97it/s]RDKit ERROR: [07:21:25] UFFTYPER: Unrecognized charge state for atom: 0
# RDKit ERROR: [07:21:25] UFFTYPER: Unrecognized charge state for atom: 4
# Optimizing mols:   0%|          | 47/10743 [00:03<17:20, 10.28it/s]RDKit ERROR: [07:21:26] UFFTYPER: Unrecognized atom type: Se2+2 (4)
# Optimizing mols:   1%|          | 58/10743 [00:05<33:41,  5.29it/s]RDKit ERROR: [07:21:29] UFFTYPER: Unrecognized charge state for atom: 0
# Optimizing mols:   1%|          | 87/10743 [00:09<17:11, 10.33it/s]RDKit ERROR: [07:21:33] UFFTYPER: Unrecognized atom type: Se2+2 (2)
# Optimizing mols:   1%|▏         | 135/10743 [00:17<12:31, 14.11it/s]  RDKit ERROR: [07:21:40] UFFTYPER: Unrecognized atom type: Mo2 (1)
# RDKit ERROR: [07:21:40] UFFTYPER: Unrecognized charge state for atom: 0
# Optimizing mols:   2%|▏         | 169/10743 [02:50<53:32,  3.29it/s]   RDKit ERROR: [07:24:14] UFFTYPER: Unrecognized atom type: Fe3 (0)
# Optimizing mols:   2%|▏         | 258/10743 [02:55<11:02, 15.83it/s]RDKit WARNING: [07:24:18] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# RDKit ERROR: [07:24:18] UFFTYPER: Unrecognized charge state for atom: 0
# Optimizing mols:   3%|▎         | 300/10743 [02:59<12:03, 14.43it/s]RDKit ERROR: [07:24:22] UFFTYPER: Unrecognized atom type: Be (0)
# Optimizing mols:   3%|▎         | 331/10743 [03:00<08:06, 21.41it/s]RDKit ERROR: [07:24:25] UFFTYPER: Unrecognized atom type: Fe3 (0)
# Optimizing mols:   3%|▎         | 342/10743 [03:02<19:23,  8.94it/s]RDKit ERROR: [07:24:26] UFFTYPER: Unrecognized charge state for atom: 7
# Optimizing mols:   3%|▎         | 348/10743 [03:03<19:51,  8.73it/s]RDKit ERROR: [07:24:26] UFFTYPER: Unrecognized atom type: V_3 (1)
# RDKit ERROR: [07:24:26] UFFTYPER: Unrecognized atom type: V_2 (4)
# RDKit ERROR: [07:24:26] UFFTYPER: Unrecognized atom type: V_2 (8)
# Optimizing mols:   4%|▎         | 382/10743 [03:08<29:01,  5.95it/s]  RDKit ERROR: [07:24:32] UFFTYPER: Unrecognized atom type: Fe3 (0)
# Optimizing mols:   4%|▎         | 387/10743 [03:09<23:28,  7.35it/s]RDKit ERROR: [07:24:32] UFFTYPER: Unrecognized charge state for atom: 7
# Optimizing mols:   4%|▍         | 426/10743 [03:15<1:15:17,  2.28it/s]RDKit WARNING: [07:24:39] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# RDKit ERROR: [07:24:39] UFFTYPER: Unrecognized charge state for atom: 0
# Optimizing mols:   5%|▍         | 486/10743 [03:20<12:07, 14.11it/s]  RDKit ERROR: [07:24:44] UFFTYPER: Unrecognized atom type: Cu5 (0)
# Optimizing mols:   5%|▍         | 513/10743 [03:22<12:50, 13.27it/s]RDKit ERROR: [07:24:45] UFFTYPER: Unrecognized atom type: W_3 (1)
# Optimizing mols:   5%|▍         | 523/10743 [03:22<09:18, 18.28it/s]RDKit WARNING: [07:24:46] UFFTYPER: Warning: hybridization set to SP3 for atom 1
UFFTYPER: Unrecognized atom type: Fe3 (0)
# Optimizing mols:   7%|▋         | 787/10743 [03:44<10:03, 16.49it/s]RDKit ERROR: [07:25:08] UFFTYPER: Unrecognized atom type: Fe1 (0)
# Optimizing mols:   7%|▋         | 798/10743 [03:45<07:10, 23.09it/s]RDKit ERROR: [07:25:08] UFFTYPER: Unrecognized charge state for atom: 6
# Optimizing mols:   8%|▊         | 807/10743 [03:46<25:10,  6.58it/s]RDKit ERROR: [07:25:10] UFFTYPER: Unrecognized charge state for atom: 1
# Optimizing mols:   8%|▊         | 835/10743 [03:49<14:35, 11.32it/s]RDKit ERROR: [07:25:16] UFFTYPER: Unrecognized atom type: Co3 (0)
# Optimizing mols:   8%|▊         | 884/10743 [04:44<1:01:11,  2.68it/s] RDKit ERROR: [07:26:07] UFFTYPER: Unrecognized atom type: Pt3 (0)
# Optimizing mols:   8%|▊         | 907/10743 [04:46<31:01,  5.28it/s]  RDKit ERROR: [07:26:10] UFFTYPER: Unrecognized atom type: Se2+2 (2)
# Optimizing mols:   9%|▊         | 916/10743 [04:47<19:17,  8.49it/s]RDKit ERROR: [07:26:10] UFFTYPER: Unrecognized charge state for atom: 92
# Optimizing mols:   9%|▊         | 919/10743 [04:48<42:51,  3.82it/s]RDKit ERROR: [07:26:12] UFFTYPER: Unrecognized charge state for atom: 1
# Optimizing mols:   9%|▉         | 981/10743 [04:53<15:09, 10.73it/s]RDKit ERROR: [07:26:17] UFFTYPER: Unrecognized atom type: Fe3 (0)
# Optimizing mols:   9%|▉         | 1001/10743 [06:37<21:05:00,  7.79s/it]RDKit ERROR: [07:28:00] UFFTYPER: Unrecognized charge state for atom: 6
# RDKit ERROR: [07:28:00] UFFTYPER: Unrecognized charge state for atom: 10
# Optimizing mols:  10%|▉         | 1026/10743 [06:45<1:16:02,  2.13it/s] RDKit ERROR: [07:28:09] UFFTYPER: Unrecognized charge state for atom: 0
# RDKit ERROR: [07:28:09] UFFTYPER: Unrecognized atom type: Gd3+3 (0)
# Optimizing mols:  14%|█▎        | 1452/10743 [07:20<12:49, 12.07it/s]  RDKit ERROR: [07:28:44] UFFTYPER: Unrecognized charge state for atom: 12
# Optimizing mols:  15%|█▌        | 1623/10743 [07:29<06:12, 24.52it/s]RDKit WARNING: [07:28:53] UFFTYPER: Warning: hybridization set to SP3 for atom 5
# Optimizing mols:  17%|█▋        | 1776/10743 [07:38<09:00, 16.60it/s]RDKit ERROR: [07:29:02] UFFTYPER: Unrecognized charge state for atom: 1
# Optimizing mols:  20%|█▉        | 2105/10743 [07:57<07:22, 19.54it/s]RDKit WARNING: [07:29:21] UFFTYPER: Warning: hybridization set to SP3 for atom 10
# Optimizing mols:  24%|██▍       | 2556/10743 [08:20<07:22, 18.50it/s]RDKit ERROR: [07:29:44] UFFTYPER: Unrecognized charge state for atom: 22
# Optimizing mols:  25%|██▌       | 2739/10743 [08:31<07:08, 18.68it/s]RDKit ERROR: [07:29:55] UFFTYPER: Unrecognized atom type: S_5+4 (5)
# Optimizing mols:  27%|██▋       | 2951/10743 [08:42<05:29, 23.66it/s]RDKit ERROR: [07:30:06] UFFTYPER: Unrecognized charge state for atom: 17
# Optimizing mols:  28%|██▊       | 3005/10743 [08:47<26:06,  4.94it/s]RDKit ERROR: [07:30:10] UFFTYPER: Unrecognized atom type: Pt3 (0)
# Optimizing mols:  28%|██▊       | 3052/10743 [09:15<1:27:02,  1.47it/s]RDKit ERROR: [07:30:38] UFFTYPER: Unrecognized atom type: Pt3 (0)
# Optimizing mols:  29%|██▊       | 3065/10743 [09:45<4:47:04,  2.24s/it] RDKit ERROR: [07:31:09] UFFTYPER: Unrecognized charge state for atom: 0
# RDKit ERROR: [07
UFFTYPER: Unrecognized atom type: Fe3 (0)
# Optimizing mols:  81%|████████▏ | 8734/10743 [49:41<03:25,  9.77it/s]RDKit ERROR: [08:11:04] UFFTYPER: Unrecognized atom type: Ca1 (0)
# Optimizing mols:  82%|████████▏ | 8782/10743 [49:44<02:20, 13.91it/s]RDKit WARNING: [08:11:07] UFFTYPER: Warning: hybridization set to SP3 for atom 5
# RDKit ERROR: [08:11:07] UFFTYPER: Unrecognized charge state for atom: 9
# Optimizing mols:  82%|████████▏ | 8848/10743 [49:49<02:53, 10.90it/s]RDKit ERROR: [08:11:12] UFFTYPER: Unrecognized atom type: Fe3 (0)
# Optimizing mols:  83%|████████▎ | 8878/10743 [49:53<04:01,  7.74it/s]RDKit ERROR: [08:11:17] UFFTYPER: Unrecognized atom type: V_3 (0)
# Optimizing mols:  83%|████████▎ | 8891/10743 [49:54<03:00, 10.28it/s]RDKit ERROR: [08:11:18] UFFTYPER: Unrecognized charge state for atom: 0
# RDKit ERROR: [08:11:18] UFFTYPER: Unrecognized atom type: Zn+2 (0)
# Optimizing mols:  84%|████████▎ | 8977/10743 [50:11<23:33,  1.25it/s]RDKit ERROR: [08:11:35] UFFTYPER: Unrecognized atom type: Ta3 (0)
# RDKit ERROR: [08:11:35] UFFTYPER: Unrecognized atom type: Ta3 (0)
# RDKit ERROR: [08:11:35] UFFTYPER: Unrecognized atom type: Ta3 (0)
# RDKit ERROR: [08:11:35] UFFTYPER: Unrecognized atom type: Ta3 (0)
# RDKit ERROR: [08:11:35] UFFTYPER: Unrecognized atom type: Ta3 (0)
# RDKit ERROR: [08:11:35] UFFTYPER: Unrecognized atom type: Ta3 (0)
# Optimizing mols:  84%|████████▍ | 9041/10743 [50:36<03:02,  9.34it/s]  RDKit ERROR: [08:11:59] UFFTYPER: Unrecognized charge state for atom: 6
# RDKit ERROR: [08:11:59] UFFTYPER: Unrecognized atom type: Se2+2 (6)
# Optimizing mols:  84%|████████▍ | 9044/10743 [50:36<04:18,  6.58it/s]RDKit ERROR: [08:12:00] UFFTYPER: Unrecognized atom type: Ru (0)
# Optimizing mols:  84%|████████▍ | 9046/10743 [50:36<03:32,  7.99it/s]RDKit ERROR: [08:12:00] UFFTYPER: Unrecognized charge state for atom: 0
# RDKit ERROR: [08:12:00] UFFTYPER: Unrecognized atom type: Zn1+2 (0)
# Optimizing mols:  84%|████████▍ | 9064/10743 [50:38<02:05, 13.35it/s]RDKit ERROR: [08:12:01] UFFTYPER: Unrecognized charge state for atom: 7
# Optimizing mols:  85%|████████▍ | 9105/10743 [50:41<02:15, 12.12it/s]RDKit ERROR: [08:12:04] UFFTYPER: Unrecognized charge state for atom: 0
# RDKit ERROR: [08:12:04] UFFTYPER: Unrecognized atom type: Cu5 (0)
# RDKit ERROR: [08:12:04] UFFTYPER: Unrecognized atom type: Cu5 (0)
# RDKit ERROR: [08:12:04] UFFTYPER: Unrecognized atom type: Cu5 (0)
# RDKit ERROR: [08:12:04] UFFTYPER: Unrecognized atom type: Cu5 (0)
# Optimizing mols:  85%|████████▌ | 9132/10743 [50:42<01:29, 17.94it/s]RDKit ERROR: [08:12:06] UFFTYPER: Unrecognized atom type: Co3 (0)
# Optimizing mols:  85%|████████▌ | 9147/10743 [50:44<03:23,  7.84it/s]RDKit ERROR: [08:12:08] UFFTYPER: Unrecognized charge state for atom: 6
# RDKit ERROR: [08:12:08] UFFTYPER: Unrecognized atom type: Se2+2 (6)
# RDKit ERROR: [08:12:08] UFFTYPER: Unrecognized atom type: As2+3 (1)
# RDKit ERROR: [08:12:08] UFFTYPER: Unrecognized atom type: As2+3 (3)
# Optimizing mols:  85%|████████▌ | 9183/10743 [50:47<01:57, 13.25it/s]RDKit ERROR: [08:12:11] UFFTYPER: Unrecognized atom type: Ru3 (0)
# Optimizing mols:  87%|████████▋ | 9296/10743 [51:00<02:18, 10.48it/s]RDKit WARNING: [08:12:24] UFFTYPER: Warning: hybridization set to SP3 for atom 3
# RDKit ERROR: [08:12:24] UFFTYPER: Unrecognized charge state for atom: 3
# Optimizing mols:  87%|████████▋ | 9305/10743 [51:01<03:10,  7.55it/s]RDKit ERROR: [08:12:27] UFFTYPER: Unrecognized atom type: Co3 (0)
# RDKit WARNING: [08:12:27] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# RDKit ERROR: [08:12:27] UFFTYPER: Unrecognized charge state for atom: 0
# RDKit ERROR: [08:12:27] UFFTYPER: Unrecognized atom type: W_3 (0)
# Optimizing mols:  87%|████████▋ | 9310/10743 [51:04<08:28,  2.82it/s]RDKit WARNING: [08:12:28] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# RDKit ERROR: [08:12:28] UFFTYPER: Unrecognized charge state for atom: 0
# Optimizing mols:  88%|████████▊ | 9432/10743 [51:19<01:59, 10.93it/s]RDKit ERROR: [08:12:43] UFFTYPER: Unrecognized atom type: Fe3 (0)
# Optimizing mols:  88%|████████▊ | 9450/10743 [51:20<01:22, 15.61it/s]RDKit ERROR: [08:12:45] UFFTYPER: Unrecognized charge state for atom: 7
# Optimizing mols:  88%|████████▊ | 9469/10743 [51:24<02:38,  8.05it/s]RDKit ERROR: [08:12:47] UFFTYPER: Unrecognized charge state for atom: 10
# Optimizing mols:  88%|████████▊ | 9487/10743 [51:25<02:00, 10.41it/s]RDKit ERROR: [08:12:49] UFFTYPER: Unrecognized charge state for atom: 0
# RDKit ERROR: [08:12:49] UFFTYPER: Unrecognized atom type: Gd3+3 (0)
# Optimizing mols:  89%|████████▉ | 9543/10743 [51:31<01:26, 13.79it/s]RDKit ERROR: [08:12:54] UFFTYPER: Unrecognized atom type: Fe3 (0)
# RDKit ERROR: [08:12:54] UFFTYPER: Unrecognized atom type: V_1 (1)
# Optimizing mols:  89%|████████▉ | 9581/10743 [51:33<01:11, 16.33it/s]RDKit ERROR: [08:12:57] UFFTYPER: Unrecognized charge state for atom: 0
# RDKit ERROR: [08:12:57] UFFTYPER: Unrecognized atom type: Zn1+2 (0)
# Optimizing mols:  90%|████████▉ | 9627/10743 [51:39<02:09,  8.64it/s]RDKit WARNING: [08:13:03] UFFTYPER: Warning: hybridization set to SP3 for atom 9
# Optimizing mols:  90%|████████▉ | 9647/10743 [51:41<01:34, 11.55it/s]RDKit ERROR: [08:13:05] UFFTYPER: Unrecognized atom type: Fe3 (0)
# Optimizing mols:  90%|████████▉ | 9659/10743 [51:42<02:05,  8.62it/s]RDKit ERROR: [08:13:06] UFFTYPER: Unrecognized atom type: Co3 (0)
# Optimizing mols:  90%|█████████ | 9679/10743 [51:44<01:25, 12.49it/s]RDKit ERROR: [08:13:07] UFFTYPER: Unrecognized charge state for atom: 2
# RDKit ERROR: [08:13:07] UFFTYPER: Unrecognized charge state for atom: 11
# RDKit ERROR: [08:13:07] UFFTYPER: Unrecognized atom type: Au5 (0)
# Optimizing mols:  91%|█████████ | 9741/10743 [51:58<01:54,  8.72it/s]RDKit ERROR: [08:13:21] UFFTYPER: Unrecognized atom type: Cu5 (0)
# Optimizing mols:  91%|█████████ | 9756/10743 [51:58<00:59, 16.60it/s]RDKit ERROR: [08:13:22] UFFTYPER: Unrecognized atom type: Fe3 (0)
# Optimizing mols:  91%|█████████ | 9790/10743 [52:05<01:51,  8.59it/s]RDKit ERROR: [08:13:29] UFFTYPER: Unrecognized charge state for atom: 9
# Optimizing mols:  91%|█████████▏| 9817/10743 [52:07<01:09, 13.38it/s]RDKit ERROR: [08:13:30] UFFTYPER: Unrecognized charge state for atom: 6
# Optimizing mols:  91%|█████████▏| 9826/10743 [52:07<00:53, 17.10it/s]RDKit ERROR: [08:13:31] UFFTYPER: Unrecognized charge state for atom: 9
# Optimizing mols:  91%|█████████▏| 9829/10743 [52:08<00:58, 15.65it/s]RDKit ERROR: [08:13:31] UFFTYPER: Unrecognized atom type: Pt3 (0)
# Optimizing mols:  92%|█████████▏| 9856/10743 [52:11<01:56,  7.64it/s]RDKit ERROR: [08:13:35] UFFTYPER: Unrecognized atom type: V_2 (1)
# Optimizing mols:  92%|█████████▏| 9872/10743 [52:13<02:01,  7.18it/s]RDKit ERROR: [08:13:37] UFFTYPER: Unrecognized atom type: Fe3 (0)
# Optimizing mols:  92%|█████████▏| 9886/10743 [52:15<02:51,  4.99it/s]RDKit ERROR: [08:13:38] UFFTYPER: Unrecognized atom type: Ca (0)
# Optimizing mols:  92%|█████████▏| 9891/10743 [52:15<02:19,  6.12it/s]RDKit ERROR: [08:13:39] UFFTYPER: Unrecognized atom type: Mo2 (1)
# RDKit ERROR: [08:13:39] UFFTYPER: Unrecognized charge state for atom: 0
# Optimizing mols:  92%|█████████▏| 9913/10743 [52:17<01:09, 11.92it/s]RDKit ERROR: [08:13:40] UFFTYPER: Unrecognized atom type: Ca (0)
# Optimizing mols:  93%|█████████▎| 9953/10743 [52:22<01:46,  7.42it/s]RDKit ERROR: [08:13:45] UFFTYPER: Unrecognized atom type: Cu5 (0)
# Optimizing mols:  93%|█████████▎| 9974/10743 [52:25<02:46,  4.62it/s]RDKit ERROR: [08:13:49] UFFTYPER: Unrecognized atom type: Fe3 (0)
# Optimizing mols:  93%|█████████▎| 9977/10743 [52:26<02:10,  5.85it/s]RDKit ERROR: [08:13:49] UFFTYPER: Unrecognized atom type: Fe3 (0)
# Optimizing mols:  93%|█████████▎| 9997/10743 [52:29<02:14,  5.54it/s]RDKit WARNING: [08:13:53] UFFTYPER: Warning: hybridization set to SP3 for atom 6
# RDKit ERROR: [08:13:53] UFFTYPER: Unrecognized charge state for atom: 6
# Optimizing mols:  93%|█████████▎| 10023/10743 [52:30<00:35, 20.30it/s]RDKit ERROR: [08:13:54] UFFTYPER: Unrecognized atom type: Pt3 (0)
# Optimizing mols:  93%|█████████▎| 10032/10743 [52:31<00:36, 19.42it/s]RDKit ERROR: [08:13:54] UFFTYPER: Unrecognized atom type: S_5+4 (11)
# Optimizing mols:  93%|█████████▎| 10041/10743 [52:31<00:40, 17.14it/s]RDKit ERROR: [08:13:55] UFFTYPER: Unrecognized charge state for atom: 0
# RDKit ERROR: [08:13:55] UFFTYPER: Unrecognized atom type: Zn1+2 (0)
# Optimizing mols:  94%|█████████▍| 10139/10743 [52:51<00:23, 25.61it/s]RDKit ERROR: [08:14:15] UFFTYPER: Unrecognized charge state for atom: 0
# RDKit ERROR: [08:14:15] UFFTYPER: Unrecognized atom type: Zn+2 (0)
# Optimizing mols:  95%|█████████▍| 10171/10743 [52:55<01:14,  7.69it/s]RDKit ERROR: [08:14:18] UFFTYPER: Unrecognized charge state for atom: 1
# RDKit ERROR: [08:14:18] UFFTYPER: Unrecognized atom type: Se2+2 (1)
# Optimizing mols:  95%|█████████▌| 10223/10743 [52:59<01:45,  4.95it/s]RDKit ERROR: [08:14:23] UFFTYPER: Unrecognized atom type: Fe3 (0)
# RDKit ERROR: [08:14:23] UFFTYPER: Unrecognized atom type: Fe3 (0)
# Optimizing mols:  96%|█████████▌| 10287/10743 [53:07<01:10,  6.50it/s]RDKit ERROR: [08:14:31] UFFTYPER: Unrecognized atom type: Fe3 (0)
# Optimizing mols:  96%|█████████▌| 10302/10743 [53:08<00:31, 14.07it/s]RDKit ERROR: [08:14:32] UFFTYPER: Unrecognized atom type: Fe3 (0)
# Optimizing mols:  96%|█████████▋| 10341/10743 [53:12<00:31, 12.81it/s]RDKit ERROR: [08:14:35] UFFTYPER: Unrecognized charge state for atom: 1
# RDKit ERROR: [08:14:35] UFFTYPER: Unrecognized charge state for atom: 0
# RDKit ERROR: [08:14:35] UFFTYPER: Unrecognized atom type: Zn1+2 (0)
# Optimizing mols:  97%|█████████▋| 10367/10743 [53:15<00:54,  6.94it/s]RDKit ERROR: [08:14:38] UFFTYPER: Unrecognized atom type: V_2 (1)
# Optimizing mols:  97%|█████████▋| 10470/10743 [53:24<00:23, 11.40it/s]RDKit WARNING: [08:14:48] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# Optimizing mols:  97%|█████████▋| 10473/10743 [53:24<00:27,  9.96it/s]RDKit ERROR: [08:14:48] UFFTYPER: Unrecognized charge state for atom: 10
# Optimizing mols:  98%|█████████▊| 10481/10743 [53:25<00:22, 11.68it/s]RDKit ERROR: [08:14:48] UFFTYPER: Unrecognized atom type: Fe3 (0)
# Optimizing mols:  98%|█████████▊| 10500/10743 [53:31<02:04,  1.95it/s]RDKit ERROR: [08:14:54] UFFTYPER: Unrecognized atom type: Ag5 (0)
# Optimizing mols:  98%|█████████▊| 10520/10743 [53:35<00:41,  5.43it/s]RDKit ERROR: [08:14:58] UFFTYPER: Unrecognized atom type: Fe3 (0)
# Optimizing mols:  98%|█████████▊| 10546/10743 [53:37<00:17, 11.23it/s]RDKit ERROR: [08:15:01] UFFTYPER: Unrecognized atom type: Fe3 (0)
# Optimizing mols:  99%|█████████▊| 10594/10743 [53:39<00:05, 27.83it/s]RDKit ERROR: [08:15:03] UFFTYPER: Unrecognized atom type: Ca (0)
# Optimizing mols:  99%|█████████▉| 10622/10743 [53:41<00:09, 13.35it/s]RDKit ERROR: [08:15:05] UFFTYPER: Unrecognized atom type: Ga2+3 (17)
# Optimizing mols:  99%|█████████▉| 10646/10743 [53:43<00:05, 16.47it/s]RDKit ERROR: [08:15:07] UFFTYPER: Unrecognized atom type: Co3 (0)
# Optimizing mols:  99%|█████████▉| 10662/10743 [53:45<00:09,  8.95it/s]RDKit ERROR: [08:15:08] UFFTYPER: Unrecognized charge state for atom: 0
# RDKit ERROR: [08:15:08] UFFTYPER: Unrecognized atom type: Zn1+2 (0)
# Optimizing mols: 100%|█████████▉| 10712/10743 [53:48<00:02, 12.15it/s]RDKit ERROR: [08:15:11] UFFTYPER: Unrecognized atom type: Fe3 (0)
# Optimizing mols: 100%|█████████▉| 10724/10743 [53:48<00:01, 14.06it/s]RDKit ERROR: [08:15:12] UFFTYPER: Unrecognized atom type: Co3 (0)
# Optimizing mols: 100%|█████████▉| 10737/10743 [53:49<00:00, 18.41it/s]RDKit ERROR: [08:15:12] UFFTYPER: Unrecognized charge state for atom: 6
# Optimizing mols: 100%|██████████| 10743/10743 [53:49<00:00,  3.33it/s]
#            cid                                        subssynonym  \
# 0       445722  DB03657|N-(methoxycarbonyl)-beta-D-glucopyrano...
# 1       448006  (+)-2-(4-biphenyl)propionic acid|2-(1,1'-BIPHE...
# 2       444719                     METHIONINE PHOSPHONATE|DB02151
# 3         4064                meprobamate|Meprobamic acid|DB00371
# 4         2131       ambenonium|Ambenonum|Ambenonium Base|DB01122
# ...        ...                                                ...
# 10616    60852                Ibandronic Acid|Ibandronate|DB00710
# 10617    92196                           4-Methylaminorex|DB01447
# 10618     3776   isopropanol|Isopropyl alcohol|2-Propanol|DB02325
# 10619     6834  BROMPHENIRAMINE|1-(p-Bromophenyl)-1-(2-pyridyl...
# 10620  5326813                                     DAS869|DB02850
#
#                                                   smiles  \
# 0      COC(=O)N[C@H]1[C@@H]([C@H]([C@@H]([C@H](O1)CO)...
# 1                C[C@@H](C1=CC=C(C=C1)C2=CC=CC=C2)C(=O)O
# 2                                  CSCC[C@H](N)P(=O)(O)O
# 3                              CCCC(C)(COC(=O)N)COC(=O)N
# 4      CC[N+](CC)(CCNC(=O)C(=O)NCC[N+](CC)(CC)CC1=CC=...
# ...                                                  ...
# 10616                CCCCCN(C)CCC(O)(P(=O)(O)O)P(=O)(O)O
# 10617                          CC1C(OC(=N1)N)C2=CC=CC=C2
# 10618                                             CC(C)O
# 10619               CN(C)CCC(C1=CC=C(C=C1)Br)C2=CC=CC=N2
# 10620  CC1=C(C=CC(=C1C2=CC=C(C=C2)OC)S(=O)(=O)C)C(=O)...
#
#                                                    rdmol  \
# 0      <img data-content="rdkit/molecule" src="data:i...
# 1      <img data-content="rdkit/molecule" src="data:i...
# 2      <img data-content="rdkit/molecule" src="data:i...
# 3      <img data-content="rdkit/molecule" src="data:i...
# 4      <img data-content="rdkit/molecule" src="data:i...
# ...                                                  ...
# 10616  <img data-content="rdkit/molecule" src="data:i...
# 10617  <img data-content="rdkit/molecule" src="data:i...
# 10618  <img data-content="rdkit/molecule" src="data:i...
# 10619  <img data-content="rdkit/molecule" src="data:i...
# 10620  <img data-content="rdkit/molecule" src="data:i...
#
#                                          rdmol_optimized
# 0      <img data-content="rdkit/molecule" src="data:i...
# 1      <img data-content="rdkit/molecule" src="data:i...
# 2      <img data-content="rdkit/molecule" src="data:i...
# 3      <img data-content="rdkit/molecule" src="data:i...
# 4      <img data-content="rdkit/molecule" src="data:i...
# ...                                                  ...
# 10616  <img data-content="rdkit/molecule" src="data:i...
# 10617  <img data-content="rdkit/molecule" src="data:i...
# 10618  <img data-content="rdkit/molecule" src="data:i...
# 10619  <img data-content="rdkit/molecule" src="data:i...
# 10620  <img data-content="rdkit/molecule" src="data:i...
#
# [10621 rows x 5 columns]

# %%
df4.to_csv('checkpoint_df4.csv', index = True)

# %% [markdown]
# Calculate (all) mordred descriptors (slow, 10k molecules = 1h)

# %%
calc = Calculator(descriptors)
df5=calc.pandas(df4['rdmol_optimized']) # create new df containing descriptors

print(len(df4),'molecules in',len(df5),'molecules out (should match!)') # make sure smiles and descriptors df's match

df5
# Out:
# 100%|██████████| 10621/10621 [1:04:29<00:00,  2.74it/s]
# 10621 molecules in 10621 molecules out (should match!)
#              ABC      ABCGG  nAcid  nBase  SpAbs_A  SpMax_A SpDiam_A   SpAD_A  \
# 0      11.589507  11.130344      0      0  19.6887  2.40062  4.80123  19.6887
# 1      12.934771  10.803382      1      0  22.0094  2.33885  4.67771  22.0094
# 2       6.888497   7.193066      2      1  10.7741  2.22015   4.4403  10.7741
# 3      10.495973  10.398546      0      0  16.7533  2.26382  4.52764  16.7533
# 4      26.479190  22.032686      0      2  45.3354  2.35799  4.71599  45.3354
# ...          ...        ...    ...    ...      ...      ...      ...      ...
# 10616  13.760274  13.462337      4      1  20.5369  2.48406  4.96813  20.5369
# 10617  10.037394   9.168374      0      2  16.7305   2.3767  4.63136  16.7305
# 10618   2.449490   2.449490      0      0   3.4641  1.73205   3.4641   3.4641
# 10619  14.389425  12.216867      0      1  24.2211  2.34963  4.69926  24.2211
# 10620  24.169465  20.470436      0      0  37.5761  2.51442  5.00965  37.5761
#
#         SpMAD_A  LogEE_A  ...      SRW10     TSRW10          MW       AMW  \
# 0       1.23055  3.65928  ...   9.588297  48.109140  237.084852  7.647898
# 1       1.29467  3.74693  ...   9.555135  49.382507  226.099380  7.293528
# 2       1.07741  3.14309  ...   8.717518  38.675269  185.027551  8.410343
# 3       1.11688  3.54923  ...   9.048880  45.566268  218.126657  6.609899
# 4       1.25932  4.46929  ...  10.329572  72.093870  536.267385  6.875223
# ...         ...      ...  ...        ...        ...         ...       ...
# 10616   1.08089  3.80788  ...   9.932415  52.262605  319.094975  7.597499
# 10617   1.28697  3.50068  ...   9.304650  58.064580  176.094963  7.043799
# 10618  0.866025  2.17806  ...   6.188264  24.179697   60.057515  5.004793
# 10619   1.27479  3.84888  ...   9.572271  51.676805  318.073161  8.370346
# 10620   1.21213  4.36139  ...  10.546840  81.345237  442.156243  7.757127
#
#       WPath WPol  Zagreb1  Zagreb2  mZagreb1  mZagreb2
# 0       432   25     76.0     88.0   7.66667  3.777778
# 1       558   24     84.0     96.0   5.80556  3.833333
# 2       130   10     42.0     43.0   5.92361  2.333333
# 3       406   16     64.0     66.0   7.78472  3.541667
# 4      4866   56    174.0    199.0   13.7917  8.500000
# ...     ...  ...      ...      ...       ...       ...
# 10616   756   29     90.0    101.0   10.7986  4.166667
# 10617   239   16     66.0     76.0   4.19444  2.888889
# 10618     9    0     12.0      9.0   3.11111  1.000000
# 10619   718   25     92.0    103.0   6.30556  4.305556
# 10620  2598   55    168.0    201.0   13.4861  6.555556
#
# [10621 rows x 1826 columns]

# %% [markdown]
# Drop descriptors containing any errors, descriptors where all values = 0, and highly correlated descriptors

# %%
df6=df5.copy()
df6=df6.applymap(lambda x: np.nan if type(x) in [mordred.error.Missing,mordred.error.Error] else x)
df6=df6.dropna(axis=1)

non_zero_std = df6.std() != 0
df6 = df6 [non_zero_std[non_zero_std].index]

threshold=0.95
df_corr = df6.corr().abs()
upper = df_corr.where(np.triu(np.ones(df_corr.shape), k=1).astype(np.bool))
to_drop = [column for column in upper.columns if any(upper[column] > threshold)]
df6 = df6.drop(to_drop, axis=1)
df6
# Out:
#              ABC  nAcid  nBase  nAromAtom  nSpiro  nBridgehead  nHetero  nB  \
# 0      11.589507      0      0          0       0            0        8   0
# 1      12.934771      1      0         12       0            0        2   0
# 2       6.888497      2      1          0       0            0        6   0
# 3      10.495973      0      0          0       0            0        6   0
# 4      26.479190      0      2         12       0            0        8   0
# ...          ...    ...    ...        ...     ...          ...      ...  ..
# 10616  13.760274      4      1          0       0            0       10   0
# 10617  10.037394      0      2          6       0            0        3   0
# 10618   2.449490      0      0          0       0            0        1   0
# 10619  14.389425      0      1         12       0            0        3   0
# 10620  24.169465      0      0         12       0            0        8   0
#
#        nN  nO  ...      JGI5      JGI6      JGI7      JGI8      JGI9  \
# 0       1   7  ...  0.035590  0.025374  0.012897  0.000000  0.000000
# 1       0   2  ...  0.028704  0.032163  0.019097  0.011450  0.010000
# 2       1   3  ...  0.033333  0.000000  0.000000  0.000000  0.000000
# 3       2   4  ...  0.021605  0.022263  0.015625  0.000000  0.000000
# 4       4   2  ...  0.022799  0.018744  0.012597  0.010736  0.007679
# ...    ..  ..  ...       ...       ...       ...       ...       ...
# 10616   1   7  ...  0.045752  0.015038  0.019886  0.017284  0.013333
# 10617   2   1  ...  0.025722  0.020245  0.027778  0.000000  0.000000
# 10618   0   1  ...  0.000000  0.000000  0.000000  0.000000  0.000000
# 10619   2   0  ...  0.021111  0.020204  0.015727  0.021007  0.005208
# 10620   2   5  ...  0.035211  0.024405  0.020771  0.013802  0.012340
#
#           JGI10     JGT10  Diameter     SRW05  WPath
# 0      0.000000  0.557250         8  0.000000    432
# 1      0.012346  0.438046        10  0.000000    558
# 2      0.000000  0.655185         6  0.000000    130
# 3      0.000000  0.617277         8  0.000000    406
# 4      0.007748  0.513551        19  0.000000   4866
# ...         ...       ...       ...       ...    ...
# 10616  0.000000  0.750406        10  0.000000    756
# 10617  0.000000  0.427170         7  2.397895    239
# 10618  0.000000  0.500000         2  0.000000      9
# 10619  0.000000  0.397608         9  0.000000    718
# 10620  0.013798  0.615753        14  2.397895   2598
#
# [10621 rows x 338 columns]

# %%
df6.to_csv('drugbank_descriptors.csv', index = True)

# %% [markdown]
# Scale the descriptors

# %%
df6.index = df6.index.astype(int)
#df6.dropna(axis=0,inplace=True)
X_all = np.array(df6)
scaler = StandardScaler()
scaler.fit(X_all)
X_all_sc = scaler.transform(X_all)

# %% [markdown]
# Run umap

# %%
clusterable_embedding = umap.UMAP(random_state=42).fit_transform(X_all_sc)

print(clusterable_embedding[0])
# Out:
# [13.586549  1.377939]

# %%
df_1 = pd.DataFrame(clusterable_embedding, columns = ['dimension 1', 'dimension 2'])
df_1
# Out:
#        dimension 1  dimension 2
# 0        13.586549     1.377939
# 1         7.037136     3.928394
# 2        12.965233     3.895618
# 3        12.105888     3.041144
# 4         7.161107    10.575061
# ...            ...          ...
# 10616    13.987025     5.628865
# 10617     9.663800     4.089830
# 10618    14.827571     2.977263
# 10619     7.558755     2.631796
# 10620     8.730027     4.623658
#
# [10621 rows x 2 columns]

# %% [markdown]
# Recheck size of df4, make sure the number of rows matches df_1

# %%
df4
# Out:
#            cid                                        subssynonym  \
# 0       445722  DB03657|N-(methoxycarbonyl)-beta-D-glucopyrano...
# 1       448006  (+)-2-(4-biphenyl)propionic acid|2-(1,1'-BIPHE...
# 2       444719                     METHIONINE PHOSPHONATE|DB02151
# 3         4064                meprobamate|Meprobamic acid|DB00371
# 4         2131       ambenonium|Ambenonum|Ambenonium Base|DB01122
# ...        ...                                                ...
# 10616    60852                Ibandronic Acid|Ibandronate|DB00710
# 10617    92196                           4-Methylaminorex|DB01447
# 10618     3776   isopropanol|Isopropyl alcohol|2-Propanol|DB02325
# 10619     6834  BROMPHENIRAMINE|1-(p-Bromophenyl)-1-(2-pyridyl...
# 10620  5326813                                     DAS869|DB02850
#
#                                                   smiles  \
# 0      COC(=O)N[C@H]1[C@@H]([C@H]([C@@H]([C@H](O1)CO)...
# 1                C[C@@H](C1=CC=C(C=C1)C2=CC=CC=C2)C(=O)O
# 2                                  CSCC[C@H](N)P(=O)(O)O
# 3                              CCCC(C)(COC(=O)N)COC(=O)N
# 4      CC[N+](CC)(CCNC(=O)C(=O)NCC[N+](CC)(CC)CC1=CC=...
# ...                                                  ...
# 10616                CCCCCN(C)CCC(O)(P(=O)(O)O)P(=O)(O)O
# 10617                          CC1C(OC(=N1)N)C2=CC=CC=C2
# 10618                                             CC(C)O
# 10619               CN(C)CCC(C1=CC=C(C=C1)Br)C2=CC=CC=N2
# 10620  CC1=C(C=CC(=C1C2=CC=C(C=C2)OC)S(=O)(=O)C)C(=O)...
#
#                                                    rdmol  \
# 0      <img data-content="rdkit/molecule" src="data:i...
# 1      <img data-content="rdkit/molecule" src="data:i...
# 2      <img data-content="rdkit/molecule" src="data:i...
# 3      <img data-content="rdkit/molecule" src="data:i...
# 4      <img data-content="rdkit/molecule" src="data:i...
# ...                                                  ...
# 10616  <img data-content="rdkit/molecule" src="data:i...
# 10617  <img data-content="rdkit/molecule" src="data:i...
# 10618  <img data-content="rdkit/molecule" src="data:i...
# 10619  <img data-content="rdkit/molecule" src="data:i...
# 10620  <img data-content="rdkit/molecule" src="data:i...
#
#                                          rdmol_optimized
# 0      <img data-content="rdkit/molecule" src="data:i...
# 1      <img data-content="rdkit/molecule" src="data:i...
# 2      <img data-content="rdkit/molecule" src="data:i...
# 3      <img data-content="rdkit/molecule" src="data:i...
# 4      <img data-content="rdkit/molecule" src="data:i...
# ...                                                  ...
# 10616  <img data-content="rdkit/molecule" src="data:i...
# 10617  <img data-content="rdkit/molecule" src="data:i...
# 10618  <img data-content="rdkit/molecule" src="data:i...
# 10619  <img data-content="rdkit/molecule" src="data:i...
# 10620  <img data-content="rdkit/molecule" src="data:i...
#
# [10621 rows x 5 columns]

# %%
df_1['CID'] = df4['cid']
df_1['names'] = df4['subssynonym']
df_1['smiles'] = df4['smiles']
df_1['rdmol_optimized'] = df4['rdmol_optimized']
df_1
# Out:
#        dimension 1  dimension 2      CID  \
# 0        13.586549     1.377939   445722
# 1         7.037136     3.928394   448006
# 2        12.965233     3.895618   444719
# 3        12.105888     3.041144     4064
# 4         7.161107    10.575061     2131
# ...            ...          ...      ...
# 10616    13.987025     5.628865    60852
# 10617     9.663800     4.089830    92196
# 10618    14.827571     2.977263     3776
# 10619     7.558755     2.631796     6834
# 10620     8.730027     4.623658  5326813
#
#                                                    names  \
# 0      DB03657|N-(methoxycarbonyl)-beta-D-glucopyrano...
# 1      (+)-2-(4-biphenyl)propionic acid|2-(1,1'-BIPHE...
# 2                         METHIONINE PHOSPHONATE|DB02151
# 3                    meprobamate|Meprobamic acid|DB00371
# 4           ambenonium|Ambenonum|Ambenonium Base|DB01122
# ...                                                  ...
# 10616                Ibandronic Acid|Ibandronate|DB00710
# 10617                           4-Methylaminorex|DB01447
# 10618   isopropanol|Isopropyl alcohol|2-Propanol|DB02325
# 10619  BROMPHENIRAMINE|1-(p-Bromophenyl)-1-(2-pyridyl...
# 10620                                     DAS869|DB02850
#
#                                                   smiles  \
# 0      COC(=O)N[C@H]1[C@@H]([C@H]([C@@H]([C@H](O1)CO)...
# 1                C[C@@H](C1=CC=C(C=C1)C2=CC=CC=C2)C(=O)O
# 2                                  CSCC[C@H](N)P(=O)(O)O
# 3                              CCCC(C)(COC(=O)N)COC(=O)N
# 4      CC[N+](CC)(CCNC(=O)C(=O)NCC[N+](CC)(CC)CC1=CC=...
# ...                                                  ...
# 10616                CCCCCN(C)CCC(O)(P(=O)(O)O)P(=O)(O)O
# 10617                          CC1C(OC(=N1)N)C2=CC=CC=C2
# 10618                                             CC(C)O
# 10619               CN(C)CCC(C1=CC=C(C=C1)Br)C2=CC=CC=N2
# 10620  CC1=C(C=CC(=C1C2=CC=C(C=C2)OC)S(=O)(=O)C)C(=O)...
#
#                                          rdmol_optimized
# 0      <img data-content="rdkit/molecule" src="data:i...
# 1      <img data-content="rdkit/molecule" src="data:i...
# 2      <img data-content="rdkit/molecule" src="data:i...
# 3      <img data-content="rdkit/molecule" src="data:i...
# 4      <img data-content="rdkit/molecule" src="data:i...
# ...                                                  ...
# 10616  <img data-content="rdkit/molecule" src="data:i...
# 10617  <img data-content="rdkit/molecule" src="data:i...
# 10618  <img data-content="rdkit/molecule" src="data:i...
# 10619  <img data-content="rdkit/molecule" src="data:i...
# 10620  <img data-content="rdkit/molecule" src="data:i...
#
# [10621 rows x 6 columns]

# %% [markdown]
# Export the final csv file

# %%
df_1.to_csv('drugbank_umap_data.csv', index = True)

# %% [markdown]
# **Misc. PubChemPy tools**
#
# Information on a particular molecule

# %%
c = pcp.Compound.from_cid(5090)

print(c.iupac_name)
print(c.synonyms[0])
print(c.molecular_formula)
print(c.molecular_weight)
print(c.isomeric_smiles)
print(c.xlogp)

# %% [markdown]
# Search for a molecule using name, smiles, sdf, inchi, inchikey, or formula

# %%
compounds = pcp.get_compounds('Glucose', 'name')
print(compounds)
for i in compounds:
    print(i.isomeric_smiles)

# %% [markdown]
# Similarity calculation

# %%
def tanimoto(compound1, compound2):
    fp1 = int(compound1.fingerprint, 16)
    fp2 = int(compound2.fingerprint, 16)
    fp1_count = bin(fp1).count('1')
    fp2_count = bin(fp2).count('1')
    both_count = bin(fp1 & fp2).count('1')
    return float(both_count) / (fp1_count + fp2_count - both_count)

mol1 = pcp.Compound.from_cid(108770)
mol2 = pcp.Compound.from_cid(2244)

tanimoto(mol1, mol2)
